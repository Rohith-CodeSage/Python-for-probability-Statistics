# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohith-CodeSage/Python-for-probability-Statistics/blob/main/2303A52198_6_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm

mu = 100
sigma = 5
data = np.random.normal(mu, sigma, 10000)

x = np.linspace(mu-3*sigma, mu+3*sigma, 10000)
pdf = norm.pdf(x, mu, sigma)
print(pdf)

plt.figure(figsize=(10,6))
plt.hist(data, bins=30, density=True ,color='blue',edgecolor = 'black')
plt.plot(x,pdf,'r-',lw =2)
plt.title('Normal distribution curve')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()
# Out:
# [0.00088637 0.00088797 0.00088957 ... 0.00088957 0.00088797 0.00088637]
